# %% [markdown]
# # E-Commerce Shipment Analysis

# %% [markdown]
# ####    E-commerce business takes place when buyer and seller conduct their business transactions with the help of internet.  In today’s competitive world, e-commerce has become the most exciting sector.
# ####    The dataset used for the analysis is a customer database of an international e-commerce company selling electronic products.
# ####   The variables of dataset are both continuous and categorical in nature. The dataset contains a unique identifier for each candidate.To analyse our dataset, NumPy and pandaslibraries were used.  Matplotlib and Seaborn were  used to visuaslize the dataset.
# #### The main goal of analysis is to:
# #### *To identify the most used mode of shipment.
# #### *To  find the  most ordered category of product.
# #### *To understand  the impact of delivery time and customer  ratings on the sale of e-commerce product of the company based on the dataset.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt   
from matplotlib import style
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the file

# %%
d=pd.read_csv("C:/Users/Roopa Sara George/Downloads/ecom.csv")

# %% [markdown]
# ### View the data

# %%
d
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %% [markdown]
# ### Drop Unnecessary column

# %%
d=d.drop(['Customer_care_calls'],axis=1)
d
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 0          1               D           Flight                2
# 1          2               F           Flight                5
# 2          3               A           Flight                2
# 3          4               B           Flight                3
# 4          5               C           Flight                2
# ...      ...             ...              ...              ...
# 10994  10995               A             Ship                1
# 10995  10996               B             Ship                1
# 10996  10997               C             Ship                4
# 10997  10998               F             Ship                2
# 10998  10999               D             Ship                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                      177                3                low      F
# ...

# %% [markdown]
# ### To rename column name

# %%
d= d.rename(columns={'ID':'cust_ID'})
d
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 0            1               D           Flight                2
# 1            2               F           Flight                5
# 2            3               A           Flight                2
# 3            4               B           Flight                3
# 4            5               C           Flight                2
# ...        ...             ...              ...              ...
# 10994    10995               A             Ship                1
# 10995    10996               B             Ship                1
# 10996    10997               C             Ship                4
# 10997    10998               F             Ship                2
# 10998    10999               D             Ship                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                      177                3                low      F
# ...

# %% [markdown]
# ### To check how many rows and columns

# %%
d.shape
# Out:
# (10999, 11)

# %% [markdown]
# ### Print the column names

# %%
d.columns
# Out:
# Index(['cust_ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_rating',
#        'Cost_of_the_Product', 'Prior_purchases', 'Product_importance',
#        'Gender', 'Discount_offered', 'Weight_in_gms', 'Reached.on.Time_Y.N'],
#       dtype='object')

# %% [markdown]
# ### To print number of dimensions

# %%
d.ndim
# Out:
# 2

# %% [markdown]
# ### To print the index

# %%
d.index
# Out:
# RangeIndex(start=0, stop=10999, step=1)

# %% [markdown]
# ### To check the size of the data

# %%
d.size
# Out:
# 120989

# %% [markdown]
# ### To check whether data type is empty or not

# %%
d.empty
# Out:
# False

# %% [markdown]
# ### To check the data type of attributes

# %%
d.dtypes
# Out:
# cust_ID                 int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Product_importance     object
# Gender                 object
# Discount_offered        int64
# Weight_in_gms           int64
# Reached.on.Time_Y.N     int64
# dtype: object

# %% [markdown]
# ### To check there is any missing values

# %%
d.isnull()
# Out:
#        cust_ID  Warehouse_block  Mode_of_Shipment  Customer_rating  \
# 0        False            False             False            False
# 1        False            False             False            False
# 2        False            False             False            False
# 3        False            False             False            False
# 4        False            False             False            False
# ...        ...              ...               ...              ...
# 10994    False            False             False            False
# 10995    False            False             False            False
# 10996    False            False             False            False
# 10997    False            False             False            False
# 10998    False            False             False            False
#
#        Cost_of_the_Product  Prior_purchases  Product_importance  Gender  \
# 0                    False            False               False   False
# ...

# %% [markdown]
# ### Sum of missing values

# %%
d.isnull().sum()
# Out:
# cust_ID                0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %% [markdown]
# ### To check for Zero or negative values in the dataset

# %%
print((d==0).sum()[(d==0).sum()>0])
# Out:
# Reached.on.Time_Y.N    4436
# dtype: int64

# %%
print((d==-1).sum()[(d==-1).sum()>0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Print the information of dataset

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cust_ID              10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_rating      10999 non-null  int64
#  4   Cost_of_the_Product  10999 non-null  int64
#  5   Prior_purchases      10999 non-null  int64
#  6   Product_importance   10999 non-null  object
#  7   Gender               10999 non-null  object
#  8   Discount_offered     10999 non-null  int64
#  9   Weight_in_gms        10999 non-null  int64
#  10  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(7), object(4)
# memory usage: 945.4+ KB

# %% [markdown]
# ### Print Statistical information

# %%
d.describe()
# Out:
#            cust_ID  Customer_rating  Cost_of_the_Product  Prior_purchases  \
# count  10999.00000     10999.000000         10999.000000     10999.000000
# mean    5500.00000         2.990545           210.196836         3.567597
# std     3175.28214         1.413603            48.063272         1.522860
# min        1.00000         1.000000            96.000000         2.000000
# 25%     2750.50000         2.000000           169.000000         3.000000
# 50%     5500.00000         3.000000           214.000000         3.000000
# 75%     8249.50000         4.000000           251.000000         4.000000
# max    10999.00000         5.000000           310.000000        10.000000
#
#        Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count      10999.000000   10999.000000         10999.000000
# mean          13.373216    3634.016729             0.596691
# std           16.205527    1635.377251             0.490584
# min            1.000000    1001.000000             0.000000
# ...

# %% [markdown]
# ### Print all Statistical information

# %%
d.describe(include='all')
# Out:
#             cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# count   10999.00000           10999            10999     10999.000000
# unique          NaN               5                3              NaN
# top             NaN               F             Ship              NaN
# freq            NaN            3666             7462              NaN
# mean     5500.00000             NaN              NaN         2.990545
# std      3175.28214             NaN              NaN         1.413603
# min         1.00000             NaN              NaN         1.000000
# 25%      2750.50000             NaN              NaN         2.000000
# 50%      5500.00000             NaN              NaN         3.000000
# 75%      8249.50000             NaN              NaN         4.000000
# max     10999.00000             NaN              NaN         5.000000
#
#         Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# ...

# %% [markdown]
# ### Check the relationship between dataset

# %%
d.corr()
# Out:
#                       cust_ID  Customer_rating  Cost_of_the_Product  \
# cust_ID              1.000000        -0.005722             0.196791
# Customer_rating     -0.005722         1.000000             0.009270
# Cost_of_the_Product  0.196791         0.009270             1.000000
# Prior_purchases      0.145369         0.013179             0.123676
# Discount_offered    -0.598278        -0.003124            -0.138312
# Weight_in_gms        0.278312        -0.001897            -0.132604
# Reached.on.Time_Y.N -0.411822         0.013119            -0.073587
#
#                      Prior_purchases  Discount_offered  Weight_in_gms  \
# cust_ID                     0.145369         -0.598278       0.278312
# Customer_rating             0.013179         -0.003124      -0.001897
# Cost_of_the_Product         0.123676         -0.138312      -0.132604
# Prior_purchases             1.000000         -0.082769      -0.168213
# Discount_offered           -0.082769          1.000000      -0.376067
# ...

# %% [markdown]
# ### Check the duplicated value

# %%
d.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10994    False
# 10995    False
# 10996    False
# 10997    False
# 10998    False
# Length: 10999, dtype: bool

# %%
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### To find the maximum values of all variables

# %%
d.apply(max)
# Out:
# cust_ID                 10999
# Warehouse_block             F
# Mode_of_Shipment         Ship
# Customer_rating             5
# Cost_of_the_Product       310
# Prior_purchases            10
# Product_importance     medium
# Gender                      M
# Discount_offered           65
# Weight_in_gms            7846
# Reached.on.Time_Y.N         1
# dtype: object

# %% [markdown]
# ### To find the minimum values of all variables

# %%
d.apply(min)
# Out:
# cust_ID                     1
# Warehouse_block             A
# Mode_of_Shipment       Flight
# Customer_rating             1
# Cost_of_the_Product        96
# Prior_purchases             2
# Product_importance       high
# Gender                      F
# Discount_offered            1
# Weight_in_gms            1001
# Reached.on.Time_Y.N         0
# dtype: object

# %% [markdown]
# ### Print unique blocks in dataset

# %%
d['Warehouse_block'].unique()
# Out:
# array(['D', 'F', 'A', 'B', 'C'], dtype=object)

# %% [markdown]
# ### Print unique modes of shipment in dataset

# %%
d['Mode_of_Shipment'].unique()
# Out:
# array(['Flight', 'Ship', 'Road'], dtype=object)

# %% [markdown]
# ### Print unique Category products in dataset

# %%
d['Product_importance'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %% [markdown]
# ### Print unique rating values in dataset

# %%
d['Customer_rating'].unique()
# Out:
# array([2, 5, 3, 1, 4], dtype=int64)

# %% [markdown]
# ### To print the top 5 rows of dataset

# %%
d.head()
# Out:
#    cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 0        1               D           Flight                2
# 1        2               F           Flight                5
# 2        3               A           Flight                2
# 3        4               B           Flight                3
# 4        5               C           Flight                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# ...

# %% [markdown]
# ### To print the bottom rows of dataset

# %%
d.tail(10)
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 10989    10990               B             Ship                1
# 10990    10991               C             Ship                4
# 10991    10992               F             Ship                2
# 10992    10993               D             Ship                1
# 10993    10994               F             Ship                1
# 10994    10995               A             Ship                1
# 10995    10996               B             Ship                1
# 10996    10997               C             Ship                4
# 10997    10998               F             Ship                2
# 10998    10999               D             Ship                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 10989                  218                5             medium      F
# 10990                  219                6                low      M
# ...

# %% [markdown]
# ### To print random data

# %%
d.sample(5)
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 6491      6492               F             Ship                4
# 8694      8695               D             Ship                5
# 7805      7806               F           Flight                2
# 10014    10015               D           Flight                3
# 1557      1558               B             Ship                1
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 6491                   251                4                low      F
# 8694                   220                3                low      F
# 7805                   219                6                low      F
# 10014                  185                2                low      M
# 1557                   148                3                low      M
#
#        Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 6491                 10           1568                    1
# ...

# %% [markdown]
# ### To extract data of products ordered by flight

# %%
m_flight=d[d['Mode_of_Shipment']=="Flight"]
m_flight
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 0            1               D           Flight                2
# 1            2               F           Flight                5
# 2            3               A           Flight                2
# 3            4               B           Flight                3
# 4            5               C           Flight                2
# ...        ...             ...              ...              ...
# 10972    10973               C           Flight                1
# 10973    10974               F           Flight                2
# 10974    10975               D           Flight                2
# 10975    10976               F           Flight                2
# 10976    10977               A           Flight                2
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                      177                3                low      F
# ...

# %% [markdown]
# ### To extract data of products ordered by ship

# %%
m_ship=d[d['Mode_of_Shipment']=="Ship"]
m_ship
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 17          18               F             Ship                5
# 18          19               D             Ship                5
# 19          20               F             Ship                5
# 20          21               A             Ship                3
# 21          22               B             Ship                1
# ...        ...             ...              ...              ...
# 10994    10995               A             Ship                1
# 10995    10996               B             Ship                1
# 10996    10997               C             Ship                4
# 10997    10998               F             Ship                2
# 10998    10999               D             Ship                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 17                     227                3             medium      M
# ...

# %% [markdown]
# ### To extract data of products ordered by road

# %%
m_road=d[d['Mode_of_Shipment']=="Road"]
m_road
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 110        111               A             Road                1
# 111        112               B             Road                2
# 112        113               C             Road                3
# 113        114               F             Road                2
# 114        115               D             Road                5
# ...        ...             ...              ...              ...
# 10950    10951               D             Road                3
# 10951    10952               F             Road                2
# 10952    10953               A             Road                1
# 10953    10954               B             Road                1
# 10954    10955               C             Road                1
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 110                    158                2                low      M
# ...

# %% [markdown]
# ### To find the total no of products ordered by road

# %%
m_road['Mode_of_Shipment'].value_counts()
# Out:
# Road    1760
# Name: Mode_of_Shipment, dtype: int64

# %% [markdown]
# ### To find the total no of products ordered by ship

# %%
m_ship['Mode_of_Shipment'].value_counts()
# Out:
# Ship    7462
# Name: Mode_of_Shipment, dtype: int64

# %% [markdown]
# ### To find the total no of products ordered by flight

# %%
m_flight['Mode_of_Shipment'].value_counts()
# Out:
# Flight    1777
# Name: Mode_of_Shipment, dtype: int64

# %% [markdown]
# ### To extract the record of all low category products by road

# %%
low_road=m_road[m_road['Product_importance']=="low"]
low_road
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 110        111               A             Road                1
# 111        112               B             Road                2
# 112        113               C             Road                3
# 113        114               F             Road                2
# 118        119               C             Road                5
# ...        ...             ...              ...              ...
# 10948    10949               C             Road                4
# 10951    10952               F             Road                2
# 10952    10953               A             Road                1
# 10953    10954               B             Road                1
# 10954    10955               C             Road                1
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 110                    158                2                low      M
# ...

# %% [markdown]
# ### To extract the record of all medium category products by road

# %%
medium_road=m_road[m_road['Product_importance']=="medium"]
medium_road
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 117        118               B             Road                3
# 121        122               F             Road                3
# 123        124               B             Road                3
# 126        127               D             Road                5
# 128        129               A             Road                4
# ...        ...             ...              ...              ...
# 10944    10945               D             Road                4
# 10946    10947               A             Road                2
# 10947    10948               B             Road                1
# 10949    10950               F             Road                4
# 10950    10951               D             Road                3
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 117                    265                2             medium      F
# ...

# %% [markdown]
#  ### To extract the record of all high category products by road

# %%
high_road=m_road[m_road['Product_importance']=="high"]
high_road
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 114        115               D             Road                5
# 115        116               F             Road                4
# 116        117               A             Road                1
# 249        250               B             Road                5
# 255        256               B             Road                2
# ...        ...             ...              ...              ...
# 10402    10403               C             Road                5
# 10523    10524               F             Road                4
# 10524    10525               D             Road                5
# 10672    10673               C             Road                2
# 10675    10676               F             Road                3
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 114                    168                2               high      M
# ...

# %% [markdown]
# ### To extract the record of all low category products by ship

# %%
low_ship=m_ship[m_ship['Product_importance']=="low"]
low_ship
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 22          23               C             Ship                5
# 25          26               F             Ship                1
# 28          29               C             Ship                3
# 29          30               F             Ship                4
# 31          32               F             Ship                3
# ...        ...             ...              ...              ...
# 10988    10989               A             Ship                3
# 10990    10991               C             Ship                4
# 10993    10994               F             Ship                1
# 10996    10997               C             Ship                4
# 10998    10999               D             Ship                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 22                     156                2                low      M
# ...

# %% [markdown]
# ### To extract the record of all medium category products by ship

# %%
medium_ship=m_ship[m_ship['Product_importance']=="medium"]
medium_ship
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 17          18               F             Ship                5
# 19          20               F             Ship                5
# 20          21               A             Ship                3
# 21          22               B             Ship                1
# 24          25               D             Ship                5
# ...        ...             ...              ...              ...
# 10991    10992               F             Ship                2
# 10992    10993               D             Ship                1
# 10994    10995               A             Ship                1
# 10995    10996               B             Ship                1
# 10997    10998               F             Ship                2
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 17                     227                3             medium      M
# ...

# %% [markdown]
# ### To extract the record of all high category products by ship

# %%
high_ship=m_ship[m_ship['Product_importance']=="high"]
high_ship
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 18          19               D             Ship                5
# 23          24               F             Ship                3
# 26          27               A             Ship                1
# 36          37               D             Ship                5
# 54          55               D             Ship                3
# ...        ...             ...              ...              ...
# 10631    10632               F             Ship                2
# 10860    10861               D             Ship                3
# 10898    10899               A             Ship                1
# 10908    10909               D             Ship                1
# 10910    10911               A             Ship                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 18                     239                3               high      M
# ...

# %% [markdown]
# ### To extract the record of all low category products by flight

# %%
low_flight=m_flight[m_flight['Product_importance']=="low"]
low_flight
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 0            1               D           Flight                2
# 1            2               F           Flight                5
# 2            3               A           Flight                2
# 6            7               D           Flight                4
# 7            8               F           Flight                1
# ...        ...             ...              ...              ...
# 10971    10972               B           Flight                5
# 10972    10973               C           Flight                1
# 10973    10974               F           Flight                2
# 10974    10975               D           Flight                2
# 10975    10976               F           Flight                2
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                      177                3                low      F
# ...

# %% [markdown]
# ### To extract the record of all medium category products by flight

# %%
medium_flight=m_flight[m_flight['Product_importance']=="medium"]
medium_flight
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 3            4               B           Flight                3
# 4            5               C           Flight                2
# 5            6               F           Flight                1
# 9           10               B           Flight                2
# 10          11               C           Flight                4
# ...        ...             ...              ...              ...
# 10963    10964               F           Flight                5
# 10967    10968               F           Flight                4
# 10968    10969               D           Flight                4
# 10969    10970               F           Flight                2
# 10976    10977               A           Flight                2
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 3                      176                4             medium      M
# ...

# %% [markdown]
# ### To extract the record of all high category products by flight

# %%
high_flight=m_flight[m_flight['Product_importance']=="high"]
high_flight
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 13          14               F           Flight                4
# 140        141               A           Flight                4
# 546        547               D           Flight                5
# 556        557               C           Flight                3
# 561        562               B           Flight                5
# ...        ...             ...              ...              ...
# 10828    10829               C           Flight                3
# 10829    10830               F           Flight                4
# 10834    10835               C           Flight                4
# 10956    10957               D           Flight                3
# 10958    10959               A           Flight                2
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 13                     275                3               high      M
# ...

# %% [markdown]
# ### Top rated customer orders

# %%
top_rating=d.sort_values(by=['Customer_rating'],ascending=False).head(100)
top_rating
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 10998    10999               D             Ship                5
# 6621      6622               B             Ship                5
# 6655      6656               F             Ship                5
# 6654      6655               D             Ship                5
# 6650      6651               A             Ship                5
# ...        ...             ...              ...              ...
# 6965      6966               F             Road                5
# 6744      6745               D             Ship                5
# 1982      1983               A             Ship                5
# 6944      6945               A             Ship                5
# 6940      6941               C             Ship                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 10998                  155                5                low      F
# ...

# %% [markdown]
# ### Top rated customer orders by road

# %%
r_top_rating=m_road.sort_values(by=['Customer_rating'],ascending=False).head(10)
r_top_rating
# Out:
#       cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 5590     5591               C             Road                5
# 2454     2455               D             Road                5
# 5880     5881               D             Road                5
# 2178     2179               D             Road                5
# 5882     5883               A             Road                5
# 2175     2176               B             Road                5
# 2174     2175               A             Road                5
# 5885     5886               F             Road                5
# 6003     6004               B             Road                5
# 9846     9847               D             Road                5
#
#       Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 5590                  195                4             medium      M
# 2454                  219                2             medium      F
# ...

# %% [markdown]
# ### Top rated customer orders by ship

# %%
s_top_rating=m_ship.sort_values(by=['Customer_rating'],ascending=False).head(100)
s_top_rating
# Out:
#       cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 17         18               F             Ship                5
# 4971     4972               B             Ship                5
# 4894     4895               C             Ship                5
# 4898     4899               A             Ship                5
# 4899     4900               B             Ship                5
# ...       ...             ...              ...              ...
# 4286     4287               A             Ship                5
# 4284     4285               D             Ship                5
# 4280     4281               A             Ship                5
# 4218     4219               D             Ship                5
# 4163     4164               F             Ship                5
#
#       Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 17                    227                3             medium      M
# ...

# %% [markdown]
# ### Top rated customer orders by flight

# %%
f_top_rating=m_flight.sort_values(by=['Customer_rating'],ascending=False).head(10)
f_top_rating
# Out:
#       cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 5488     5489               C           Flight                5
# 3421     3422               F           Flight                5
# 3698     3699               A           Flight                5
# 9056     9057               A           Flight                5
# 9057     9058               B           Flight                5
# 3576     3577               D           Flight                5
# 3572     3573               A           Flight                5
# 3566     3567               A           Flight                5
# 9176     9177               A           Flight                5
# 3563     3564               F           Flight                5
#
#       Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 5488                  268                3             medium      M
# 3421                  159                2                low      M
# ...

# %% [markdown]
# ### Grouping cost and weight of products as per Workhouse

# %%
group=d.groupby(["Warehouse_block"]).agg({"Cost_of_the_Product":"sum","Weight_in_gms":"sum"})
group
# Out:
#                  Cost_of_the_Product  Weight_in_gms
# Warehouse_block
# A                             382671        6627118
# B                             388888        6664240
# C                             387114        6674560
# D                             386805        6655305
# F                             766477       13349327

# %% [markdown]
# ### Total cost of products ordered from workhouse A

# %%
group["Cost_of_the_Product"].iloc[1]
# Out:
# 388888

# %% [markdown]
# ### Total quantity of products ordered from workhouse F

# %%
group["Weight_in_gms"].iloc[-1]
# Out:
# 13349327

# %% [markdown]
# ### Creating pivot table from the dataset

# %%
table=d.copy()
table=table.pivot_table('Cost_of_the_Product',columns='Mode_of_Shipment',aggfunc='sum')
table
# Out:
# Mode_of_Shipment     Flight    Road     Ship
# Cost_of_the_Product  371938  370437  1569580

# %% [markdown]
# ### Creating dataframe of categorywise cost of product

# %%
df=d.copy()
df=df.groupby(['Product_importance'])['Cost_of_the_Product'].sum()
df=pd.DataFrame(df)
df
# Out:
#                     Cost_of_the_Product
# Product_importance
# high                             193270
# low                             1123281
# medium                           995404

# %% [markdown]
# ### To show relation between Warehouse and Product category

# %%
pd.crosstab(d['Warehouse_block'],d['Product_importance'])
# Out:
# Product_importance  high   low  medium
# Warehouse_block
# A                    165   909     759
# B                    146   855     832
# C                    168   874     791
# D                    166   883     785
# F                    303  1776    1587

# %% [markdown]
# ### To display the record of high category product

# %%
high_cat=d.loc[(d['Product_importance']=="high")]
high_cat
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 13          14               F           Flight                4
# 18          19               D             Ship                5
# 23          24               F             Ship                3
# 26          27               A             Ship                1
# 36          37               D             Ship                5
# ...        ...             ...              ...              ...
# 10898    10899               A             Ship                1
# 10908    10909               D             Ship                1
# 10910    10911               A             Ship                5
# 10956    10957               D           Flight                3
# 10958    10959               A           Flight                2
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 13                     275                3               high      M
# ...

# %% [markdown]
# ### To display the record of medium category product

# %%
medium_cat=d.loc[(d['Product_importance']=="medium")]
medium_cat
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 3            4               B           Flight                3
# 4            5               C           Flight                2
# 5            6               F           Flight                1
# 9           10               B           Flight                2
# 10          11               C           Flight                4
# ...        ...             ...              ...              ...
# 10991    10992               F             Ship                2
# 10992    10993               D             Ship                1
# 10994    10995               A             Ship                1
# 10995    10996               B             Ship                1
# 10997    10998               F             Ship                2
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 3                      176                4             medium      M
# ...

# %% [markdown]
# ### To display the record of low category product

# %%
low_cat=d.loc[(d['Product_importance']=="low")]
low_cat
# Out:
#        cust_ID Warehouse_block Mode_of_Shipment  Customer_rating  \
# 0            1               D           Flight                2
# 1            2               F           Flight                5
# 2            3               A           Flight                2
# 6            7               D           Flight                4
# 7            8               F           Flight                1
# ...        ...             ...              ...              ...
# 10988    10989               A             Ship                3
# 10990    10991               C             Ship                4
# 10993    10994               F             Ship                1
# 10996    10997               C             Ship                4
# 10998    10999               D             Ship                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                      177                3                low      F
# ...

# %% [markdown]
# ### To calculate cost of genderwise high category product

# %%
high_f=np.sum(high_cat.where(high_cat["Gender"]=="F")["Cost_of_the_Product"])
high_f
# Out:
# 93923.0

# %%
high_m=np.sum(high_cat.where(high_cat["Gender"]=="M")["Cost_of_the_Product"])
high_m
# Out:
# 99347.0

# %% [markdown]
# ### To calculate cost of genderwise medium category product

# %%
medium_f=np.sum(medium_cat.where(medium_cat["Gender"]=="F")["Cost_of_the_Product"])
medium_f
# Out:
# 504784.0

# %%
medium_m=np.sum(medium_cat.where(medium_cat["Gender"]=="M")["Cost_of_the_Product"])
medium_m
# Out:
# 490620.0

# %% [markdown]
# ### To calculate total weight of categorywise product by flight

# %%
weight_hf=high_flight.loc[:,"Weight_in_gms"]
weight_hf=np.sum(weight_hf)
weight_hf
# Out:
# 663389

# %%
weight_mf=medium_flight.loc[:,"Weight_in_gms"]
weight_mf=np.sum(weight_mf)
weight_mf
# Out:
# 2822830

# %%
weight_lf=low_flight.loc[:,"Weight_in_gms"]
weight_lf=np.sum(weight_lf)
weight_lf
# Out:
# 2963186

# %% [markdown]
# ### To calculate cost of categorywise product ordered by flight

# %%
cost_lf=np.sum(m_flight.where(m_flight["Product_importance"]=="low")["Cost_of_the_Product"])
cost_mf=np.sum(m_flight.where(m_flight["Product_importance"]=="medium")["Cost_of_the_Product"])
cost_hf=np.sum(m_flight.where(m_flight["Product_importance"]=="high")["Cost_of_the_Product"])

# %% [markdown]
# ### To create dictionary of cost and weight of products as per category

# %%
dicty={"Category":['Low','Medium','High'],"Weight":[weight_lf,weight_mf,weight_hf],"Cost":[cost_lf,cost_mf,cost_hf]}
dicty=pd.DataFrame(dicty)
dicty
# Out:
#   Category   Weight      Cost
# 0      Low  2963186  176714.0
# 1   Medium  2822830  162206.0
# 2     High   663389   33018.0

# %% [markdown]
# ### Listing distinct mode of shipment

# %%
l=list(d.loc[:,"Mode_of_Shipment"].unique())
l.sort()
print(l,end=" ")
# Out:
# ['Flight', 'Road', 'Ship']

# %% [markdown]
# ### Calculating total cost of products as per mode of shipment

# %%
l1=[]
for i in l:
    a=np.sum(d.where(d["Mode_of_Shipment"]==i)["Cost_of_the_Product"])
    l1.append(a)
print(l1,end=" ")
# Out:
# [371938.0, 370437.0, 1569580.0]

# %% [markdown]
# ### Creating dataframe from the list

# %%
l3=pd.DataFrame(l1,l)
l3
# Out:
#                 0
# Flight   371938.0
# Road     370437.0
# Ship    1569580.0

# %% [markdown]
# ### check relationship between data of top rated orders

# %%
s_top_rating.corr()
# Out:
#                       cust_ID  Customer_rating  Cost_of_the_Product  \
# cust_ID              1.000000              NaN             0.224364
# Customer_rating           NaN              NaN                  NaN
# Cost_of_the_Product  0.224364              NaN             1.000000
# Prior_purchases      0.115977              NaN             0.105429
# Discount_offered    -0.619951              NaN            -0.031010
# Weight_in_gms       -0.118765              NaN            -0.475292
# Reached.on.Time_Y.N -0.023482              NaN             0.238826
#
#                      Prior_purchases  Discount_offered  Weight_in_gms  \
# cust_ID                     0.115977         -0.619951      -0.118765
# Customer_rating                  NaN               NaN            NaN
# Cost_of_the_Product         0.105429         -0.031010      -0.475292
# Prior_purchases             1.000000          0.023673      -0.014777
# Discount_offered            0.023673          1.000000      -0.048612
# ...

# %% [markdown]
# ### check relationship between data of medium category orders

# %%
medium_ship.corr()
# Out:
#                       cust_ID  Customer_rating  Cost_of_the_Product  \
# cust_ID              1.000000        -0.037338             0.191292
# Customer_rating     -0.037338         1.000000             0.016864
# Cost_of_the_Product  0.191292         0.016864             1.000000
# Prior_purchases      0.106667        -0.002042             0.104228
# Discount_offered    -0.594307         0.037074            -0.136966
# Weight_in_gms        0.299954         0.005631            -0.106633
# Reached.on.Time_Y.N -0.424257         0.029327            -0.053382
#
#                      Prior_purchases  Discount_offered  Weight_in_gms  \
# cust_ID                     0.106667         -0.594307       0.299954
# Customer_rating            -0.002042          0.037074       0.005631
# Cost_of_the_Product         0.104228         -0.136966      -0.106633
# Prior_purchases             1.000000         -0.071683      -0.141221
# Discount_offered           -0.071683          1.000000      -0.387431
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ### Cost of Top rated products sold from various Warehouses

# %%
plt.bar(top_rating['Warehouse_block'],top_rating['Cost_of_the_Product'],color='green')
ax=plt.axes()
ax.set_facecolor('yellow')
plt.title('Warehouse Vs cost',fontsize=15,color='blue')
plt.xlabel('Warehouse',fontsize=15)
plt.ylabel('Cost',fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Category distribution of products of the Company

# %%
plt.title('Category',fontsize=20)
d['Product_importance'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ### Catplot of top rated products as per categorywise ordered by ship

# %%
sns.catplot(x='Warehouse_block',y='Cost_of_the_Product',col='Reached.on.Time_Y.N',hue='Product_importance',kind='point',data=s_top_rating)
plt.show()

# %% [markdown]
# ### Heatmap of top rated products ordered by ship

# %%
sns.heatmap(s_top_rating.corr(),cmap='RdBu',linewidth=1,linecolor='green')
plt.show()

# %% [markdown]
# ### Heatmap of medium categorized products ordered by ship

# %%
sns.heatmap(medium_ship.corr(),cmap='RdBu',linewidth=1,linecolor='yellow')
plt.show()

# %% [markdown]
# ###  Total Quantity of highly ctegorized products ordered by ship

# %%
sns.swarmplot(high_ship['Weight_in_gms'])
plt.show()

# %% [markdown]
# ### Cost and Weight of medium products ordered by ship from different warehouses of the company

# %%
m_ship.groupby('Warehouse_block')[['Cost_of_the_Product','Weight_in_gms']].sum().plot.bar(color=['blue','green'],figsize=(8,5))
plt.ylabel('Cost and Weight')
plt.show()

# %% [markdown]
# ### Top products ordered by road from various warehouses

# %%
m=m_road.head(100)

# %%
plt.figure(figsize=(12,8))
plt.title('Category wise cost of product from each warehouse')
sns.barplot(x='Warehouse_block',y='Cost_of_the_Product',data=m,hue='Product_importance',palette='inferno_r')
plt.xlabel('Warehouse',fontsize=15)
plt.show()

# %% [markdown]
# ### Distplot of discount offered for medium products ordered by ship

# %%
plt.figure(figsize=(8,5))
sns.distplot(medium_ship["Discount_offered"],
             bins=20,
             kde_kws={"lw":8,'color':'xkcd:bluish green'},
             hist_kws={'alpha':0.3,'color':'red'})
plt.xlabel('DISCOUNTS',fontsize=16,labelpad=15)
plt.yticks([])
plt.show()

# %% [markdown]
# ### Prior purchases of  products ordered from company by flight

# %%
sns.kdeplot(medium_flight['Prior_purchases'],medium_flight['Customer_rating'],color='green',shade=True)
plt.show()

# %% [markdown]
# ### Discounts offered for products ordered by ship per category

# %%
sns.violinplot(x='Warehouse_block',y='Discount_offered',hue='Product_importance',data=m_ship)
plt.show()

# %% [markdown]
#  ### Amount of high level products delivered from various warehouses by flight

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Warehouse_block',data=high_flight,palette='rocket_r',order=high_flight['Warehouse_block'].value_counts().index)
plt.xlabel('Warehouse',fontsize=25)
plt.xticks(rotation=360)
plt.show()

# %% [markdown]
# ### Catplot of various category products ordered by flight

# %%
sns.catplot(x='Warehouse_block',y='Cost_of_the_Product',col='Reached.on.Time_Y.N',hue='Product_importance',kind='point',data=m_flight)
plt.show()

# %% [markdown]
# ### Distplot of discount offered for high products ordered by flight

# %%
plt.figure(figsize=(8,5))
sns.distplot(high_flight["Discount_offered"],
             bins=20,
             kde_kws={"lw":8,'color':'xkcd:sky blue'},
             hist_kws={'alpha':0.3,'color':'green'})
plt.xlabel('DISCOUNTS',fontsize=16,labelpad=15)
plt.yticks([])
plt.show()

# %% [markdown]
# ### Cost of various category products ordered by flight based on their delivery time

# %%
sns.boxplot(x='Product_importance',y='Cost_of_the_Product',hue='Reached.on.Time_Y.N',width=0.7,data=m_flight)
plt.show()

# %% [markdown]
# ### Pairplot of products ordered by flight

# %%
sns.pairplot(m_flight[m_flight.Product_importance.isin(["high","medium","low"])],
             hue='Product_importance',
             vars=['Customer_rating','Prior_purchases','Reached.on.Time_Y.N'],
             palette='bright'
            )
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### The dataset used for the analysis contains 10999 observations of 12 variables. The main insights of the analysis include:
# #### >The mode of shipment of highest rated orders by customers are by ship.
# #### >The most ordered products are medium category products, whereas the least ordered are of high category.
# #### >Customer Rating has an important role in the sale of e-commerce products.
# #### >From this customer dataset of the company,it shows the delivery time has least impact with product importance or customer rating.
